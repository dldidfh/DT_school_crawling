# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EC%A0%9C%EC%A1%B0&p=1'

response = requests.get(url)

# %%
if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    print(soup)
else:
    print('{} 응답.'.format(response.status_code))
# Out:
# <!DOCTYPE html>
#
# <html class="unix unknown" lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="off" name="autocomplete"/>
# <meta content="always" name="referrer"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="제조 – Daum 검색" property="og:title"/>
# <meta content="https://search.daum.net/search?w=news&amp;q=%EC%A0%9C%EC%A1%B0" property="og:url"/>
# <meta content="Daum 검색에서 제조에 대한 최신정보를 찾아보세요." property="og:description"/>
# <meta content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" property="og:image"/>
# <meta content="다음검색" property="og:site_name"/>
# <title>제조 – Daum 검색</title>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="Daum" type="application/opensearchdescription+xml"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2021/p_common.1014034136.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2021/p_component.0915091640.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2021/p_collection.0915091640.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2021/p_collection2.1006090426.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2021/p_coll_tab.0803041653.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# var SF, C, T;
# var uk = "YWp2iGbvl4X30x6MDH3JIQAAAC8";
# var mk = "YWp2iGbvl4X30x6MDH3JIQAAAC8";
# var ud = "";
# var uuid = "";
# var adid = "";
# var adid_enabled = "N";
# var viewio = "i";
# var viewsite = "";
# var ServerTime = "20211016155152";
# var EnQuery = "%C1%A6%C1%B6";
# var utf8Query = "%EC%A0%9C%EC%A1%B0";
# var topQuery = "제조";
# var backQuery = "%EC%A0%9C%EC%A1%B0";
# var login_yn = "N";
# var encodeType = "2";
# var refCode = "";
# var bucketType = "";
# var name_check = "0";
# var mobileDevice = "N";
# var param_w="news";
# var param_da = "PGD";
# var paramCfg = "";
# var param_cnucc = "";
# var tpl_cfg = "";
# var cnucc = "";
# var usrIp = "121.160.184.204";
# var isDetailTab = "N";
# var schSort = "";
# var width_over_620 = "N";
#
# var isReleaseMode = "";
#
# var KAKAO_ACCOUNT_ID_CONNECTED = "N";
#
# var displayInfo = {"SER":[{"code":"NNS","doc_count":10}],"SGR":[{"code":"R03","doc_count":0},{"code":"R12","doc_count":0},{"code":"R05","doc_count":0},{"code":"TOG","doc_count":0},{"code":"NSJ","doc_count":0},{"code":"DCC","doc_count":0},{"code":"EOA","doc_count":0},{"code":"MBK","doc_count":0},{"code":"DRU","doc_count":0}],"SUI":[]}
# ;
# var slCallType = "sync";
# var pageLoadedTime = 0;
# var startTime = new Date().getTime();
# var sugLocCode = "";
# var searchLog = {
# uc: 0,
# clickCount: 0,
# dl: ""
# };
# var SEARCHLOGDOMAIN = "//sl.search.daum.net";
#
# var CNUCC_URL = "//harm.search.daum.net/api/harmRegister";
# </script>
# <script id="answer-korea-weather-template" type="text/html">
# <span class="weather_comp">
# <span class="txt_exact ico_suggest" data-bind="css: icon40">
# <span class="tit" data-bind="text: areaname"></span>
# <span class="cont"><span class="txt_cont" data-bind="text: wtext5s"></span> <span class="txt_num1 ico_suggest2 ico_celsius" data-bind="text: temp"></span><span class="txt_unit">℃</span></span>
# </span>
# <span class="txt_time" data-bind="text: (announce + ' 기준') "></span>
# </span>
# </script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/polyfill/p/polyfill.p.common.20200707150840.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/vendor/p/common/vendor.p.common.20210614193738.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/log/p_log.min.20211007143552.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/common/module.p.common.20210726112603.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/search/module.p.search.20210726112603.min.js" type="text/javascript"></script>
# <script>
# (function(SF, $, SL) {
# Object.assign(SF, {
# logStaticErrors: {
# isArgonUrl: function(url) {
# return url.indexOf('argon') !== -1;
# },
# extractArgonId: function(url) {
# return url.split('/').pop();
# },
# createFreeLogParams: function(ids) {
# return {
# timg: ids.join(',')
# };
# },
# chunkCall: function (fn, options) {
# var chunk = [];
# var debounced = $.debounce(function() {
# if (chunk.length > 0) {
# fn(chunk);
# chunk = [];
# }
# }, options.timeout);
# return function (arg) {
# chunk.push(arg);
# if (chunk.length >= options.chunkSize) {
# fn(chunk);
# chunk = [];
# }
# debounced();
# };
# },
# init: function() {
# this.subscribe();
# },
# subscribe: function() {
# if (!('addEventListener' in document)) {
# return;
# }
# var sendLog = this.chunkCall(this.sendLog.bind(this), {
# timeout: 1000,
# chunkSize: 50
# });
# var onError = this.onError.bind(this, sendLog);
# this.unsubscribe = function () {
# window.removeEventListener('error', onError);
# };
# window.addEventListener('error', onError, true);
# },
# onError: function (callback, event) {
# var src = event.target.src;
# if (typeof src === 'string' && this.isArgonUrl(src)) {
# callback(this.extractArgonId(src));
# }
# },
# sendLog: function(argonIds) {
# var params = this.createFreeLogParams(argonIds);
# SL.freelog.send(params);
# },
# unsubscribe: $.noop
# }
# });
# })(window.SF || {}, window.jQuery, window.SL || {});
# SF.logStaticErrors.init();
# </script>
# <script type="text/javascript">
# SF.loadModuleList = {
# "amcharts":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/library/p/amcharts.20190321202015.min.js",
# "calendar":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/calendar/module.p.calendar.20210312112039.min.js",
# "chart":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/library/p/chart.20200602182334.min.js",
# "kakaosdk":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/library/p/kakaosdk.20190321202015.min.js",
# "kakaotv":"//tv.kakao.com/player/script/sdk/player_api.min.js",
# "pagenavigation":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/pagenavigation/module.p.pagenavigation.20191016171910.min.js",
# "youtube":"//www.youtube.com/player_api"
# };
# </script>
# <script type="text/javascript">
# (function(SF) {
# Object.assign(SF, {
# phase: 'prod'
# });
# })(window.SF);
# </script>
# <!--[if IE]>
# <script src="//search1.daumcdn.net/search/statics/common/js/g/html5.min.js"></script>
# <![endif]-->
# </meta></head>
# <body class="daum">
# <script type="text/javascript">
# SL.mkeyLog();
# </script>
# <nav class="d_direct" id="daumIndex">
# <a class="link_direct" href="#daumBody">본문 바로가기</a>
# <a class="link_direct" href="#daumGnb">메뉴 바로가기</a>
# <a class="link_direct" href="#realtimeIssueTitle">실시간이슈 바로가기</a>
# </nav>
# <div id="tooltipContent"></div> <!-- TT -->
# <div id="saq" style="display:none">제조</div>
# <article class="sch_tab_news" id="daumWrap">
# <header id="daumHead">
# <div class="inner_header" id="innerHeader">
# <h1>
# <a href="https://www.daum.net/?nil_profile=daum&amp;nil_src=search" id="daumLogo" onclick='smartLog(this, "e=1&amp;dc=MLC", event);' target="_top" title="Daum 메인페이지로 가기">
# <img alt="Daum" height="34" src="//search1.daumcdn.net/search/statics/common/pi/logo/daumlogo_170324.png" width="84"/>
# </a>
# <span class="screen_out" id="daumServiceLogo">검색</span>
# </h1>
# <form class="d_sch" id="daumSearch" method="get" name="search">
# <fieldset class="fld_total">
# <legend class="screen_out">검색폼</legend>
# <input id="nil_suggest" name="nil_suggest" type="hidden" value="btn"/>
# <input id="nil_ch" name="nil_ch" type="hidden" value=""/>
# <input name="rtupcoll" type="hidden" value=""/>
# <input name="w" type="hidden" value="news"/>
# <input name="m" type="hidden" value=""/>
# <input id="f" name="f" type="hidden" value=""/>
# <input name="lpp" type="hidden" value=""/>
# <input name="DA" type="hidden" value="SBC"/>
# <input name="sug" type="hidden" value=""/>
# <input name="sq" type="hidden" value=""/>
# <input name="o" type="hidden" value=""/>
# <input name="sugo" type="hidden" value=""/>
# <input name="cluster" type="hidden" value="y"/>
# <div class="box_searchbar">
# <div class="inner_searchbar">
# <input autocomplete="off" class="tf_keyword" id="q" maxlength="255" name="q" spellcheck="false" title="검색어 입력" type="text" value="제조"/>
# <button class="img_keyboard btn_key" id="VKIBtn" onclick="SF.virtualKeyboardHandler.call();smartLog(this, 'pg=1&amp;p=1&amp;r=1&amp;rc=1&amp;dc=BFJ&amp;at=func',event);return false;" type="button"><span class="ir_wa">한글입력기</span></button>
# <button class="ico_ksearch btn_ksearch" id="daumBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </div>
# <div class="wrap_suggestBox" id="wrap_suggestBox"><div class="suggestBox box_sub" id="suggestBox"></div></div>
# </fieldset>
# </form>
# <script type="text/javascript">
# (function(){
# var headerSearchModule = new SF.HeaderSearchForm();
# headerSearchModule.init();
# })();
# </script>
# <div id="wrapMinidaum"></div>
# <div class="keyboard_layer" id="VKILayout" style="display:none;"></div>
# <div class="cl_b"></div>
# </div>
# <div id="daumGnb">
# <div class="wrap_gnb">
# <ul class="gnb_search">
# <li class="">
# <a class="tab tab_total" href="?w=tot&amp;q=%EC%A0%9C%EC%A1%B0&amp;DA=NTB" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'><span class="inner_tab"><span class="txt_tab">통합검색</span></span></a>
# </li>
# <li class="">
# <a class="tab tab_img" href="?w=img&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=2&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">이미지</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_vclip" href="?w=vclip&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=3&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">동영상</span></span>
# </a>
# </li>
# <li class="on">
# <span class="screen_out">선택된 항목</span>
# <a class="tab tab_news" href="?w=news&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;cluster=y&amp;cluster_page=1&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=4&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">뉴스</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_blog" href="?w=blog&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=5&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">블로그</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_cafe" href="?w=cafe&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;ASearchType=1&amp;lpp=10&amp;rlang=0&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=6&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">카페</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_webdoc" href="?w=web&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;lpp=10&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=7&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">웹문서</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_site" href="?w=site&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;lpp=10&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=8&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">사이트</span></span>
# </a>
# </li>
# </ul>
# <div class="more_search">
# <a class="btn_tab" href="javascript:;" id="gnbToggleBtn">
# <span class="txt_btn">더보기/접기</span>
# </a>
# <ul class="list_more">
# <li class="">
# <a class="link_more tab_dic" href="http://dic.daum.net/search.do?q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=9&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=DICZ&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">어학사전</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_map" href="http://map.daum.net/?from=total&amp;nil_suggest=btn&amp;tab=place&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=10&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=GG1Z&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">지도</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_dic100" href="http://100.daum.net/search/entry?q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=11&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=1DVZ&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">백과사전</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_shop" href="https://shoppinghow.kakao.com/search/%EC%A0%9C%EC%A1%B0/&amp;srchhow=Cexpo" onclick='smartLog(this, "pg=1&amp;r=12&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=SNPZ&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">쇼핑</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_book" href="?w=book&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=13&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=LB0Z&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">책</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_music" href="?w=music&amp;m=song&amp;nil_search=btn&amp;DA=NTB&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=14&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=MS2Z&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">멜론뮤직</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_brunch" href="?w=brunch&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=15&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=BRCZ&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">브런치</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_kstory" href="?w=kstory&amp;nil_search=btn&amp;DA=NTB&amp;q=%EC%A0%9C%EC%A1%B0" onclick='smartLog(this, "pg=1&amp;r=16&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=KASZ&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">카카오스토리</span></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# _jsSetCookieNonEscape = function(name,value){
# document.cookie = name+"="+value+"; path=/;";
# };
# _jsSetCookieNonEscape("ODT", "IIMZ_VO2Z_NNSZ_BR1Z_CCBZ_WSAZ_IVRZ_");
# _jsSetCookieNonEscape("DDT", "DICZ_GG1Z_1DVZ_SNPZ_LB0Z_MS2Z_BRCZ_KASZ_");
# _jsSetCookieNonEscape("DTQUERY", "%EC%A0%9C%EC%A1%B0" );
#
#
# </script>
# <form method="get" name="cUccForm">
# <input name="kword" type="hidden"/>
# <input name="colid" type="hidden"/>
# <input name="docid" type="hidden"/>
# <input name="backurl" type="hidden"/>
# </form>
# <form method="get" name="urForm">
# <input name="q" type="hidden"/>
# </form>
# <div class="clr"></div>
# <!-- // daumGnb -->
# <div class="skiptonavi" id="searchData" name="searchData"></div>
# <!-- End Header -->
# </header>
# <script id="suggest-footer-template" type="text/html">
# <div>
# <span>
# <div class="fr">
# <a href="http://cs.daum.net/faq/15/14957.html#28978" class="isSuggest" target="_blank" onclick="smartLog(this, 'dc=SUG&p=5&r=1', event);">서제스트란?</a>
# </div>
# </span>
# </div>
# </script>
# <article id="daumContent">
# <div id="cMain">
# <script type="text/javascript">
# searchLog.dl = 'R030_R120_R050_TOG0_NSJ0_DCC0_NNS11_PGD1_RNN1_MNN1_RSN1_EOA1_DRU1_MBK1';	/* ISM DISPLAY_RESULT */
# var smDisCode = "";
# var smClickCode = "";
# var smCateCode = "";
# var totCollCount = "1";
# var sPageLoadedmsTime = 309;
# var requestTime = "1634367112437";
# </script>
# <article id="mArticle">
# <div class="inner_article">
# <span class="screen_out" id="daumBody">검색 본문</span>
# <div class="g_comp" disp-attr="NSJ" style="position: relative;">
# <script type="text/javascript">
# /**
# * 관련검색어 pc용 스크립트
# * 바로가기 니즈 키워드 (기준 CTR 50% 이상) 인 경우 관련검색어 노출을 확대해서(3줄 펼치기 형태) 관련검색어 클릭을 높인다 - 2013.11.5 로직 삭제
# */
# (function (jq) {
# C.netizenColl = C.netizenColl || {};
# C.netizenColl = {
# applyTopBottom: function (position) {
# var NetizenToggle = function (type) {
# this.type = (type) ? type : "";
# this.btnEl = jq("#netizen_more_btn_" + type);
# this.btnTextEl = jq("#netizen_more_btn_" + type + " span.ico_rwd");
# this.listsWrapper = jq("#netizen_lists_" + this.type);
# this.lists = jq("#netizenColl_" + this.type + " .list_keyword span.wsn");
# this.listKeywords = jq("#netizenColl_" + this.type + " .list_keyword span.wsn a.keyword");
# this.tab = this.listsWrapper.data("w");
# this.listFoldClass = (this.tab == "img") ? "type1" : "type2";   /* 이미지는 기본 1줄, 나머지는 기본 2줄 노출 */
# this.listOpenClass = "type3";   /* 쵀대 4줄 노출 */
# };
# NetizenToggle.prototype = {
# init: function () {
# if (this.btnEl.length > 0) {
# this.setListType();
# this.btnEl.unbind("click").bind("click", jq.proxy(this.toggle, this));
# this.listKeywords.unbind("click").bind("click", jq.proxy(this.sendLog, this));
# jq(window).resize(jq.proxy(this.setListType, this));
# }
# },
# setListType: function () {
# var lineCount = this.getLineCount();
# switch (lineCount) {
# case 1:
# this.setBtnStatus("more", "hide");
# this.listsWrapper[0].className = "list_keyword";
# break;
# case 2:
# if (this.tab == "img") {
# if (this.listsWrapper.hasClass("type3")) {
# this.setBtnStatus("fold", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listOpenClass;
# } else {
# this.setBtnStatus("more", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# }
# } else {
# this.setBtnStatus("more", "hide");
# this.listsWrapper[0].className = "list_keyword";
# }
# break;
# case 3:
# case 4:
# if (this.tab == "img") {
# if (this.listsWrapper.hasClass("type1") || this.listsWrapper.hasClass("type2")) {
# this.setBtnStatus("more", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# } else {
# this.listsWrapper[0].className = "list_keyword " + this.listOpenClass;
# }
# } else {
# this.setBtnStatus("more", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# }
# break;
# }
# },
# setBtnStatus: function (opt1, opt2) {
# if (opt1 == "more") {
# this.btnEl.removeClass("fold");
# this.btnTextEl.text('더보기');
# } else if (opt1 == "fold") {
# this.btnEl.addClass("fold");
# this.btnTextEl.text('접기');
# }
# if (typeof(opt2) != "undefined") {
# if (opt2 == "hide") {
# jq(this.btnEl).addClass("hide");
# } else if (opt2 == "show") {
# jq(this.btnEl).removeClass("hide");
# }
# }
# },
# toggle: function (e) {
# var lineCount = this.getLineCount();
# var logData = this.btnEl.data("log");
# if (lineCount > 1) {
# if (this.btnEl.length > 0) {
# if (this.btnEl.hasClass("fold")) {
# this.setBtnStatus("more");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# smartLog(this.btnEl, logData + "&e=2", e);
# } else {
# this.setBtnStatus("fold");
# this.listsWrapper[0].className = "list_keyword " + this.listOpenClass;
# smartLog(this.btnEl, logData + "&e=1", e);
# }
# }
# }
# },
# getLineCount: function () {
# var list = this.lists[this.lists.length - 1];
# var top = jq(list).position().top;
# var lineHeight = 25;
# var margin = 5;
# /* 한 줄이 25 */
# if (top >= lineHeight * 3 && top >= lineHeight * 3 - margin) {  /* 70~75 */
# return 4;
# } else if (top >= lineHeight * 2 && top >= lineHeight * 2 - margin) { /* 45~50 */
# return 3;
# } else if (top >= lineHeight && top >= lineHeight - margin) {    /* 20~25 */
# return 2;
# } else {    /* ~20 */
# return 1;
# }
# },
# sendLog: function (e) {
# e.stopPropagation();
# var target = function () {
# if (e.target.tagName.toLowerCase() == "span") {
# return e.target.firstChild;
# } else if (e.target.tagName.toLowerCase() == "a") {
# return e.target;
# }
# }();
# var log = jq(target).data("log");
# var extra = {
# "relkwd": {
# "click_query": jq(target).text()
# }
# };
# smartLog(target, log, e, extra);
# }
# };
# var netizenToggle;
# netizenToggle = new NetizenToggle(position);
# netizenToggle.init();
# /* 이미지 탭에서 상단 관련검색어 미들 top 사이즈 체크할 때, 렌더링 타이밍 이슈로 넣어 둠. */
# setTimeout(function () {
# netizenToggle.setListType();
# }, 0);
# },
# applyRight: function () {
# /* ie6, ie7, ipad 가 아니면 */
# if (!((SF.ua.browser.name == "msie" && (SF.ua.browser.version.major == "6" || SF.ua.browser.version.major == "7")) || (SF.ua.browser.name == "ipad"))) {
# this.fixTop();
# }
# var listKeywords = jq("#netizenColl_right .list_keyword a.link_txt");
# listKeywords.unbind("click").bind("click", jq.proxy(this.sendLog, this));
# },
# sendLog: function (e) {
# e.stopPropagation();
# var target = function () {
# if (e.target.tagName.toLowerCase() == "span") {
# return e.target.parentNode;
# } else if (e.target.tagName.toLowerCase() == "a") {
# return e.target;
# }
# }();
# var log = jq(target).data("log");
# var freeLog = {
# "relkwd": {
# "click_query": jq(target).text()
# }
# };
# smartLog(target, log, e, freeLog);
# },
# fixTop: function () {
# var netizenEl = jq("#netizenColl_right")[0];
# if (netizenEl) {
# var bodyHeight = jq("#daumWrap")[0].clientHeight;
# if (viewsite == "0001L") {
# /* SA일경우 */
# var headerHeight = jq("#bingHead")[0].clientHeight;
# var footerHeight = jq("#bingFoot")[0].clientHeight;
# } else {
# var headerHeight = jq("#daumHead")[0].clientHeight;
# var footerHeight = jq("#daumFoot")[0].clientHeight;
# }
# var netizenHeight = netizenEl.clientHeight;
# var netizenTop = 0;
# var offset = 60;
# /* 우하단 맨위로 버튼으로 인한 오프셋  */
# var prevHeight = 0;
# var browserHeight = 0;
# var checkNetizen = function () {
# var currentNetizenTop = Math.round(jq(netizenEl).position().top);
# if (currentNetizenTop !== -1) {
# netizenTop = currentNetizenTop;
# }
# var isHorizontalScrollbar = document.documentElement.scrollWidth > document.documentElement.clientWidth;
# var scrollTop = getScrollOffsets().top;
# browserHeight = getWindowSize().height;
# var fixMode = ((scrollTop - headerHeight) >= netizenTop) ? true : false;
# if (isHorizontalScrollbar) {
# fixMode = false;
# }
# if (fixMode) {
# jq(netizenEl).addClass("netizen_fixed");
# if (scrollTop > (bodyHeight - (netizenHeight + footerHeight + offset))) {
# netizenEl.style.top = bodyHeight - (footerHeight + offset + netizenHeight) - scrollTop + "px";
# } else {
# netizenEl.style.top = "-1px";
# }
# } else {
# jq(netizenEl).removeClass("netizen_fixed");
# }
# };
# var getScrollOffsets = function () {
# return {
# 'left': window.pageXOffset || document.documentElement.scrollLeft || document.body.scrollLeft,
# 'top': window.pageYOffset || document.documentElement.scrollTop || document.body.scrollTop
# };
# };
# var getWindowSize = function () {
# var w = (window.innerWidth || document.documentElement.clientWidth || document.body.clientWidth || 1003) - 2,
# h = (window.innerHeight || document.documentElement.clientHeight || document.body.clientHeight || 650) - 2;
# return {"width": w, "height": h};
# };
# checkNetizen();
# jq(window).scroll(checkNetizen);
# jq(window).resize(function () {
# /* 브라우저 리사이즈시에는 높이가 달라졌을때는 클래스 순간 지움. (위치 새로 잡기위해) */
# if (prevHeight == browserHeight) {
# jq(netizenEl).removeClass("netizen_fixed");
# }
# checkNetizen();
# prevHeight = browserHeight;
# });
# }
# }
# };
# /**
# * pc 우측 박스용 말줄임
# */
# C.netizenColl.ellipsis = {
# FRONT_MARGIN: 0,
# ADDITIONAL_MARGIN: 15,
# /**
# 1. 25byte 이상인 서브키가 몇개인지 측정
# 2. 그 글자들과 메인키의 일치비율 측정 => 편집거리 사용.
# 2-1. 키워드와 똑같이 잘라서 편집거리 측정
# 3. 일치비율 >= 0.5 이상이면 중간말줄임, 아니면 기본 말줄임
# */
# draw: function () {
# var _this = this;
# var keyword = decodeURIComponent(utf8Query).replace(/\s/g, "");
# var longKeyword = this.getLongSubkey();
# if (longKeyword.length > 0) {
# var editDistances = jq.map(longKeyword, function (subkey) {
# /* 2-1 단계 */
# var cuttingSubkey = subkey.replace(/\s/g, "").substring(0, keyword.length);
# return _this.getEditDistance(_this.hangulToJaso(keyword), _this.hangulToJaso(cuttingSubkey));
# });
# var sumOfEditDistances = 0;
# jq.each(editDistances, function (index, value) {
# sumOfEditDistances += value;
# });
# var avgOfEditDistances = sumOfEditDistances / editDistances.length;
# var zeroCnt = jq.grep(editDistances, function (dist) {
# return dist <= avgOfEditDistances;
# }).length;
# var sumOfDiffSquare = 0;
# jq.each(editDistances, function (index, dist) {
# sumOfDiffSquare += Math.pow(dist - avgOfEditDistances, 2);
# });
# var matchRatio = zeroCnt / longKeyword.length;
# var variance = sumOfDiffSquare / editDistances.length;
# /* 일치비율이 0.5 이상이거나 0.3 이상이지만 분산이 2보다 작을때는 중간 말줄임 적용(프로그램명 n회 같은 쿼리는 일치비율이 작게 나오기 때문) */
# if (matchRatio >= 0.5 || (matchRatio >= 0.3 && variance < 2)) {
# this.setMiddleEllipsis();
# } else {
# this.setFullSubkey();
# }
# } else {
# this.setFullSubkey();
# }
# },
# /**
# * 25byte 이상인 키워드 몇개인지 측정
# */
# getLongSubkey: function () {
# var _this = this;
# return jq.map(jq("#netizenColl_right .txt_keyword"), function (elem, index) {
# var subkey = jq(elem).attr("data");
# if (_this.getByte(subkey) >= 25) {
# return subkey;
# }
# });
# },
# /**
# * 한글도 2byte로 계산하는 바이트 계산 함수
# */
# getByte: function (s, b, i, c) {
# for (b = i = 0; c = s.charCodeAt(i++); b += c >> 7 ? 2 : 1);
# return b;
# },
# /**
# * 한글 자소 분리
# * brunch B.Util.js 의 hangulToJaso 가져와서 사용.
# */
# hangulToJaso: function (text) {
# var ChoSeong = [0x3131, 0x3132, 0x3134, 0x3137, 0x3138,
# 0x3139, 0x3141, 0x3142, 0x3143, 0x3145, 0x3146, 0x3147, 0x3148,
# 0x3149, 0x314a, 0x314b, 0x314c, 0x314d, 0x314e];
# var JungSeong = [0x314f, 0x3150, 0x3151, 0x3152, 0x3153,
# 0x3154, 0x3155, 0x3156, 0x3157, 0x3158, 0x3159, 0x315a, 0x315b,
# 0x315c, 0x315d, 0x315e, 0x315f, 0x3160, 0x3161, 0x3162, 0x3163];
# var JongSeong = [0x0000, 0x3131, 0x3132, 0x3133, 0x3134,
# 0x3135, 0x3136, 0x3137, 0x3139, 0x313a, 0x313b, 0x313c, 0x313d,
# 0x313e, 0x313f, 0x3140, 0x3141, 0x3142, 0x3144, 0x3145, 0x3146,
# 0x3147, 0x3148, 0x314a, 0x314b, 0x314c, 0x314d, 0x314e];
# var chars = [];
# var v = [];
# for (var i = 0; i < text.length; i++) {
# chars[i] = text.charCodeAt(i);
# if (chars[i] >= 0xAC00 && chars[i] <= 0xD7A3) {
# var i1, i2, i3;
# i3 = chars[i] - 0xAC00;
# i1 = i3 / (21 * 28);
# i3 = i3 % (21 * 28);
# i2 = i3 / 28;
# i3 = i3 % 28;
# v.push(String.fromCharCode(ChoSeong[parseInt(i1)]));
# v.push(String.fromCharCode(JungSeong[parseInt(i2)]));
# if (i3 != 0x0000)
# v.push(String.fromCharCode(JongSeong[parseInt(i3)]));
# }
# else {
# v.push(String.fromCharCode(chars[i]));
# }
# }
# return v.join("");
# },
# /**
# * 편집거리 측정
# */
# getEditDistance: function (a, b) {
# if (a.length === 0) return b.length;
# if (b.length === 0) return a.length;
# var matrix = [];
# /* increment along the first column of each row */
# var i;
# for (i = 0; i <= b.length; i++) {
# matrix[i] = [i];
# }
# /* increment each column in the first row */
# var j;
# for (j = 0; j <= a.length; j++) {
# matrix[0][j] = j;
# }
# /* Fill in the rest of the matrix */
# for (i = 1; i <= b.length; i++) {
# for (j = 1; j <= a.length; j++) {
# if (b.charAt(i - 1) == a.charAt(j - 1)) {
# matrix[i][j] = matrix[i - 1][j - 1];
# } else {
# matrix[i][j] = Math.min(matrix[i - 1][j - 1] + 1, /* substitution */
# Math.min(matrix[i][j - 1] + 1, /* insertion */
# matrix[i - 1][j] + 1)); /* deletion */
# }
# }
# }
# return matrix[b.length][a.length];
# },
# /**
# * 중간 말줄임 적용
# */
# setMiddleEllipsis: function () {
# var width = 0;
# width = (jq("#netizenColl_right .list_keyword").width()) / 2;
# if (width <= 0) {
# this.setFullSubkey();
# return;
# }
# width = width - this.FRONT_MARGIN - this.ADDITIONAL_MARGIN;
# /* width 보다 넓으면 한글자씩 빼기 */
# jq.each(jq("#netizenColl_right .txt_keyword"), function (index, elem) {
# var subkey = jq(elem).attr("data");
# var len = subkey.length;
# jq(elem).text(subkey);
# var mid = len / 2;
# var removeLen = 2;
# var head, tail;
# while (jq(elem).width() > width) {
# head = subkey.substring(0, mid - removeLen / 2);
# tail = subkey.substring(mid + removeLen / 2, len);
# jq(elem).text(head + "..." + tail);
# removeLen++;
# }
# });
# },
# setFullSubkey: function () {
# jq.each(jq("#netizenColl_right .txt_keyword"), function (index, elem) {
# var subkey = jq(elem).attr("data");
# jq(elem).text(subkey);
# });
# }
# };
# jq(document).ready(function () {
# if (jq("#netizenColl_top").length > 0) {
# C.netizenColl.applyTopBottom("top");
# }
# if (jq("#netizenColl_bottom").length > 0) {
# C.netizenColl.applyTopBottom("bottom");
# }
# if (jq("#netizenColl_right").length > 0) {
# C.netizenColl.applyRight();
# C.netizenColl.ellipsis.draw();
# }
# });
# })(jQuery);
# </script>
# <div class="section_related" id="netizenColl_top">
# <div class="list_keyword type2" data-w="news" id="netizen_lists_top">
# <h2 class="tit">
# 관련 <span class="screen_out">검색어</span>
# </h2>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=1&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%EC%97%85&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%EC%97%85&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제조업</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=2&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%20%EB%9C%BB&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%20%EB%9C%BB&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제조 뜻</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=3&amp;p=1&amp;e1=%EC%A0%9C%EC%9E%91&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%9E%91&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제작</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=4&amp;p=1&amp;e1=%EC%83%9D%EC%82%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%83%9D%EC%82%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">생산</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=5&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%EC%9D%BC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%EC%9D%BC&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제조일</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=6&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%ED%95%98%EB%8B%A4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%ED%95%98%EB%8B%A4&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제조하다</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=7&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%EC%82%AC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%EC%82%AC&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제조사</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=8&amp;p=1&amp;e1=%EC%9E%AC%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9E%AC%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">재조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=9&amp;p=1&amp;e1=%EA%B0%80%EA%B3%B5&amp;rc=1" href="?w=news&amp;m=&amp;q=%EA%B0%80%EA%B3%B5&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">가공</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=10&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%20%EA%B8%B0%EC%88%A0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%20%EA%B8%B0%EC%88%A0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제조 기술</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=11&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%20%EC%98%81%EC%96%B4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%20%EC%98%81%EC%96%B4&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제조 영어</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=12&amp;p=1&amp;e1=%EC%A1%B0%EC%A0%9C&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A1%B0%EC%A0%9C&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">조제</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=13&amp;p=1&amp;e1=%EC%9D%8C%EB%A3%8C%20%EC%A0%9C%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%8C%EB%A3%8C%20%EC%A0%9C%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">음료 제조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=14&amp;p=1&amp;e1=%EC%BB%A4%ED%94%BC%20%EC%A0%9C%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%BB%A4%ED%94%BC%20%EC%A0%9C%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">커피 제조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=15&amp;p=1&amp;e1=%EC%A0%9C%ED%92%88&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%ED%92%88&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제품</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=16&amp;p=1&amp;e1=%EC%A0%9C%EB%8F%84&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EB%8F%84&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">제도</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=17&amp;p=1&amp;e1=%EB%AC%BC%ED%92%88%20%EC%A0%9C%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EB%AC%BC%ED%92%88%20%EC%A0%9C%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">물품 제조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=18&amp;p=1&amp;e1=%ED%99%94%EC%9E%A5%ED%92%88%20%EC%A0%9C%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%ED%99%94%EC%9E%A5%ED%92%88%20%EC%A0%9C%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">화장품 제조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=19&amp;p=1&amp;e1=%EC%9C%A0%ED%86%B5&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9C%A0%ED%86%B5&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">유통</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=20&amp;p=1&amp;e1=%EC%83%9D%EC%82%B0%EA%B3%BC%20%EC%A0%9C%EC%A1%B0%EC%9D%98%20%EC%B0%A8%EC%9D%B4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%83%9D%EC%82%B0%EA%B3%BC%20%EC%A0%9C%EC%A1%B0%EC%9D%98%20%EC%B0%A8%EC%9D%B4&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=NSJ">생산과 제조의 차이</a></span>
# </div>
# <a class="expender hide" data-log="dc=NSJ&amp;at=func" href="javascript:;" id="netizen_more_btn_top"> <span class="ico_rwd">더보기</span>
# </a>
# </div>
# </div>
# <div class="g_comp" disp-attr="(TAB)news" style="position: relative;">
# <div id="newsColl"> <div class="cont_divider"> <div class="coll_tit"> <h2 class="tit">뉴스</h2> <div class="info_adsch info_fairtrade"> <a class="ico_rwd ico_info" href="javascript:;">서비스 안내</a> <div class="layer_ad" style="display: none;"> <p class="f_eb">다음뉴스 안내 및 문의는 <a href="https://cs.daum.net/faq/63.html" target="_blank">다음뉴스 고객센터</a>를 이용해 주세요.</p> <button class="btn_close" type="button"><span class="ico_rwd ico_close_s">서비스 안내 레이어 닫기</span></button> </div> </div> <div class="sort_comm" data-option-type="sort"> <a class="btn_sort" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=1&amp;rc=1&amp;at=func" data-sort="accuracy" href="javascript:;">정확도순</a> <span class="ico_dot"></span> <a class="btn_sort" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=2&amp;rc=1&amp;at=func" data-sort="recency" href="javascript:;">최신순</a> <span class="ico_dot"></span> <a class="btn_sort" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=17&amp;rc=1&amp;at=func" data-sort="old" href="javascript:;">오래된순</a> </div> <div class="sub_expander"> <span class="txt_info" id="resultCntArea">1-10 / 약 4,220,000건</span> <div class="wrap_btn"> <a href="?w=news&amp;req=tab&amp;q=%EC%A0%9C%EC%A1%B0&amp;cluster=n&amp;viewio=i&amp;repno=0&amp;n=10&amp;p=1&amp;pattern_yn=n&amp;DA=STC" id="linkClusterClose" onclick='smartLog(this, "dc=STC&amp;pg=1&amp;r=1&amp;p=11&amp;rc=1&amp;sd=&amp;ed=", event);'><button class="btn_flex"><span class="inner">관련뉴스 닫기</span></button></a> <button class="btn_flex btn_search_option btn_fold"> <span class="inner">검색옵션<span class="ico_tabopt ico_arr">닫기</span></span> </button> </div> </div> </div> <div class="compo-tabopt"> <div class="box_opt"> <div class="menu_opt" data-option-type="period"> <a class="tit_menu" href="javascript:;"> <span class="label">기간</span><span class="ico_more">옵션더보기</span> </a> <div class="layer_opt"> <ul class="list_opt"> <li> <a class="tit_item" data-label="전체" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=3&amp;rc=1&amp;at=func" data-period="" href="javascript:;"> 전체 </a> </li> <li> <a class="tit_item" data-label="최근 1일" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=4&amp;rc=1&amp;at=func" data-period="d" href="javascript:;"> 최근 1일 </a> </li> <li> <a class="tit_item" data-label="최근 1주" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=5&amp;rc=1&amp;at=func" data-period="w" href="javascript:;"> 최근 1주 </a> </li> <li> <a class="tit_item" data-label="최근 1개월" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=6&amp;rc=1&amp;at=func" data-period="m" href="javascript:;"> 최근 1개월 </a> </li> <li> <a class="tit_item" data-label="최근 6개월" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=13&amp;rc=1&amp;at=func" data-period="6m" href="javascript:;"> 최근 6개월 </a> </li> <li> <a class="tit_item" data-label="최근 1년" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=14&amp;rc=1&amp;at=func" data-period="y" href="javascript:;"> 최근 1년 </a> </li> </ul> <div class="box_sub box_date" data-period="u"> <strong class="tit_other">직접입력</strong> <div class="item_date"> <input class="tf_txt" id="datepicker" title="검색기간 시작일" type="text" value="2016.01.01"> <a class="btn_date" href="javascript:;"> <img alt="Select date" class="ui-datepicker-trigger" src="https://search1.daumcdn.net/search/statics/common/pi/ico/ico_calendar.gif" title="Select date"> </img></a> </input></div> <div class="item_date"> <input class="tf_txt" id="" title="검색기간 종료일" type="text" value="2016.01.01"> <a class="btn_date" href="javascript:;"> <img alt="Select date" class="ui-datepicker-trigger" src="https://search1.daumcdn.net/search/statics/common/pi/ico/ico_calendar.gif" title="Select date"/> </a> </input></div> <button class="btn_confirm" data-log="dc=STC&amp;pg=1&amp;r=1&amp;p=7&amp;rc=1&amp;at=func" type="submit">적용</button> </div> </div> </div> <div class="menu_opt" data-option-type="cpname"> <a class="tit_menu" href="javascript:;"> <span class="label">언론사</span><span class="ico_more">옵션더보기</span> </a> <div class="layer_opt ty_news"> <div class="area_head"> <strong class="tit ff_dot">언론사</strong> <span class="info_select">총<em class="f_blue f ...
# </div>
# <div class="line"></div><hr/>
# <div disp-attr="DCC">
# <div class="section_related" id="netizenColl_bottom">
# <div class="list_keyword type2" data-w="news" id="netizen_lists_bottom">
# <h2 class="tit">
# 관련 <span class="screen_out">검색어</span>
# </h2>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=1&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%EC%97%85&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%EC%97%85&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제조업</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=2&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%20%EB%9C%BB&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%20%EB%9C%BB&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제조 뜻</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=3&amp;p=1&amp;e1=%EC%A0%9C%EC%9E%91&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%9E%91&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제작</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=4&amp;p=1&amp;e1=%EC%83%9D%EC%82%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%83%9D%EC%82%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">생산</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=5&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%EC%9D%BC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%EC%9D%BC&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제조일</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=6&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%ED%95%98%EB%8B%A4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%ED%95%98%EB%8B%A4&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제조하다</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=7&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%EC%82%AC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%EC%82%AC&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제조사</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=8&amp;p=1&amp;e1=%EC%9E%AC%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9E%AC%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">재조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=9&amp;p=1&amp;e1=%EA%B0%80%EA%B3%B5&amp;rc=1" href="?w=news&amp;m=&amp;q=%EA%B0%80%EA%B3%B5&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">가공</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=10&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%20%EA%B8%B0%EC%88%A0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%20%EA%B8%B0%EC%88%A0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제조 기술</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=11&amp;p=1&amp;e1=%EC%A0%9C%EC%A1%B0%20%EC%98%81%EC%96%B4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EC%A1%B0%20%EC%98%81%EC%96%B4&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제조 영어</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=12&amp;p=1&amp;e1=%EC%A1%B0%EC%A0%9C&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A1%B0%EC%A0%9C&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">조제</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=13&amp;p=1&amp;e1=%EC%9D%8C%EB%A3%8C%20%EC%A0%9C%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%8C%EB%A3%8C%20%EC%A0%9C%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">음료 제조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=14&amp;p=1&amp;e1=%EC%BB%A4%ED%94%BC%20%EC%A0%9C%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%BB%A4%ED%94%BC%20%EC%A0%9C%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">커피 제조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=15&amp;p=1&amp;e1=%EC%A0%9C%ED%92%88&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%ED%92%88&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제품</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=16&amp;p=1&amp;e1=%EC%A0%9C%EB%8F%84&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%A0%9C%EB%8F%84&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">제도</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=17&amp;p=1&amp;e1=%EB%AC%BC%ED%92%88%20%EC%A0%9C%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EB%AC%BC%ED%92%88%20%EC%A0%9C%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">물품 제조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=18&amp;p=1&amp;e1=%ED%99%94%EC%9E%A5%ED%92%88%20%EC%A0%9C%EC%A1%B0&amp;rc=1" href="?w=news&amp;m=&amp;q=%ED%99%94%EC%9E%A5%ED%92%88%20%EC%A0%9C%EC%A1%B0&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">화장품 제조</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=19&amp;p=1&amp;e1=%EC%9C%A0%ED%86%B5&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9C%A0%ED%86%B5&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">유통</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=20&amp;p=1&amp;e1=%EC%83%9D%EC%82%B0%EA%B3%BC%20%EC%A0%9C%EC%A1%B0%EC%9D%98%20%EC%B0%A8%EC%9D%B4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%83%9D%EC%82%B0%EA%B3%BC%20%EC%A0%9C%EC%A1%B0%EC%9D%98%20%EC%B0%A8%EC%9D%B4&amp;nzq=%EC%A0%9C%EC%A1%B0&amp;DA=DCC">생산과 제조의 차이</a></span>
# </div>
# <a class="expender hide" data-log="dc=DCC&amp;at=func" href="javascript:;" id="netizen_more_btn_bottom"> <span class="ico_rwd">더보기</span>
# </a>
# </div>
# </div>
# </div> <!-- // inner_article -->
# </article> <!-- // mArticle -->
# <aside id="mAside">
# <div class="g_comp_s" disp-attr="(TAB)news_RIGHT_APPEND">
# <div class="content_news"> <div class="coll_tit"> <h2 class="tit">많이 본 뉴스</h2> </div> <div class="coll_cont mg_cont" id="total_main_news_tabs"> <div class="tab_comp tab_box"> <ul class="list_tab tab_size3" id="news_tab_wrapper"> <li class="on"> <a class="tab_tit" href="javascript:;" onclick="SF.C.news.changeTab(this,'news')"> <span class="inner_tit">뉴스</span> </a> </li> <li> <a class="tab_tit" href="javascript:;" onclick="SF.C.news.changeTab(this, 'entertain')"> <span class="inner_tit">연예</span> </a> </li> <li> <a class="tab_tit" href="javascript:;" onclick="SF.C.news.changeTab(this, 'sports')"> <span class="inner_tit">스포츠</span> </a> </li> </ul> </div> <ul class="list_major" id="news_tab"> <li> <a class="link_major" href="https://v.daum.net/v/20211016133402323" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=1", event);' target="_blank">여자들과 2:2 술자리 미팅하려고..20대 직장인 '교묘한 수법'</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016130107048" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=2", event);' target="_blank">'강남 3억' 서울 반값아파트 가속도..주민반발 어쩌나</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016124103913" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=3", event);' target="_blank">13살에 갱단, 사람도 죽였다.. 나이키 회장 56년 지나 고백</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016133259311" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=4", event);' target="_blank">이재명 "구속될 사람은 윤석열, 이해못할 우연 너무 많아"</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016130021038" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=5", event);' target="_blank">[단독] 슬리퍼 차림 나타난 남욱, 긴급여권 발급..'곧 귀국'</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016150532344" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=6", event);' target="_blank">홍준표, 토론회 혹평에 '발끈'.."이번 대선서 중요한 건 도덕성"(종합)</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016132429226" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=7", event);' target="_blank">이재명, 2016년7월 월례조회 "업자 민원은 천사의 얼굴을 한 마귀"</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016123524873" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=8", event);' target="_blank">'대장동 공문의 최종 결재자' 비난에 이재명 측 "그래서 뭐?"</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016150104256" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=9", event);' target="_blank">아침 식사 때 피해야 할 메뉴 5</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016133117291" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=1&amp;r=10", event);' target="_blank">이경식 전 부총리 별세..금융실명제 정착시킨 YS정부 경제통(종합)</a> </li> </ul> <ul class="list_major" id="entertain_tab" style="display:none"> <li> <a class="link_major" href="https://v.daum.net/v/20211016133408325" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=2&amp;r=1", event);' target="_blank">'전참시' 육준서, 역대급 스펙의 친동생 공개..깜짝 놀랄 형제의 비밀</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016143730013" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=2&amp;r=2", event);' target="_blank">스티븐 킹이 꼽은 '오징어게임' 명대사, "같이 좀 먹고 삽시다"..영어자막 "닥치고 계란 잡아"[MD할리우드]</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016141534749" onclick='smartLog(this, "s=NS&amp;a=MNNS&amp;dc=MNN&amp;pg=1&amp;hi=0&amp;rc=1&amp;p=2&amp;r=3", event);' target="_blank">'신사와 아가씨' 지현우 이세희 손 잡았다..머리띠 쓰고 놀이동산 데이트</a> </li> <li> <a class="link_major" href="https://v.daum.net/v/20211016133634349" ...
# <div class="g_comp_s" disp-attr="R03">
# <div class="content_realtime" id="randomCategoryColl"> <div class="coll_tit"> <h2 class="tit">분야별 검색어</h2> <div class="mg_expander"><span class="f_nb">10.16. 15:51</span></div> </div> <div class="coll_cont" id="randomCategoryCollDetail"> <div class="tab_comp tab_box"> <ul class="list_tab tab_size3" id="rtissue_categories"> <li class="on"><a class="tab_tit" href="javascript:;" onclick="C.randomCategoryColl.switchTab(0, 'R03', event)"><span class="inner_tit">시사교양tv</span></a></li> <li><a class="tab_tit" href="javascript:;" onclick="C.randomCategoryColl.switchTab(1, 'R12', event)"><span class="inner_tit">연극</span></a></li> <li><a class="tab_tit" href="javascript:;" onclick="C.randomCategoryColl.switchTab(2, 'R05', event)"><span class="inner_tit">라디오방송</span></a></li> </ul> </div> <div class="wrap_rank"> <ol class="list_rank"> <li> <div class="inner_item"> <span class="num_rank">1</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=R03&amp;q=%EA%B7%B8%EA%B2%83%EC%9D%B4%20%EC%95%8C%EA%B3%A0%20%EC%8B%B6%EB%8B%A4&amp;rtmaxcoll=R0T,TVP&amp;irt=tv-program&amp;irk=48438" onclick="smartLog(this,'dc=R03&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=1',event);">그것이 알고 싶다</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">2</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=R03&amp;q=%EC%8B%9D%EA%B0%9D%20%ED%97%88%EC%98%81%EB%A7%8C%EC%9D%98%20%EB%B0%B1%EB%B0%98%EA%B8%B0%ED%96%89&amp;rtmaxcoll=R0T,TVP&amp;irt=tv-program&amp;irk=85831" onclick="smartLog(this,'dc=R03&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=2',event);">식객 허영만의 백반기행</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">3</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=R03&amp;q=%EC%B5%9C%EA%B3%A0%EC%9D%98%20%EC%9A%94%EB%A6%AC%EB%B9%84%EA%B2%B0&amp;rtmaxcoll=R0T,TVP&amp;irt=tv-program&amp;irk=47960" onclick="smartLog(this,'dc=R03&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=3',event);">최고의 요리비결</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">4</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=R03&amp;q=%EB%82%98%EB%8A%94%20%EC%9E%90%EC%97%B0%EC%9D%B8%EC%9D%B4%EB%8B%A4&amp;rtmaxcoll=R0T,TVP&amp;irt=tv-program&amp;irk=61815" onclick="smartLog(this,'dc=R03&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=4',event);">나는 자연인이다</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">5</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=R03&amp;q=%EA%BC%AC%EB%A6%AC%EC%97%90%20%EA%BC%AC%EB%A6%AC%EB%A5%BC%20%EB%AC%B4%EB%8A%94%20%EA%B7%B8%EB%82%A0%20%EC%9D%B4%EC%95%BC%EA%B8%B0&amp;rtmaxcoll=R0T,TVP&amp;irt=tv-program&amp;irk=92546" onclick="smartLog(this,'dc=R03&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=5',event);">꼬리에 꼬리를 무는 그날 이야기</a></span> </div> </li> </ol> <ol class="list_rank"> <li> <div class="inner_item"> <span class="num_rank">6</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=R03&amp;q=%EB%8B%B9%EC%8B%A0%EC%9D%B4%20%ED%98%B9%ED%95%98%EB%8A%94%20%EC%82%AC%EC%9D%B4%20%EC%8B%9C%EC%A6%8C%202&amp;rtmaxcoll=R0T,TVP&amp;irt=tv-program&amp;irk=91417" onclick="smartLog(this,'dc=R03&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=6',event);">당신이 혹하는 사이 시즌 2</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">7</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=R03&amp;q=%EC%8B%9C%EB%8C%80%EB%A5%BC%20%EB%B0%94%EA%BE%BC%20%EC%95%84%ED%8B%B0%EC%8A%A4%ED%8A%B8%20%EB%8D%B0%EB%B7%94%EC%9D%98%20%EC%88%9C%EA%B0%84&amp;rtmaxcoll=R0T,TVP&amp;irt=tv-program&amp;irk=92653" onclick="smartLog(this,'dc=R03&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=7',event);">시대를 바꾼 아티스트 데뷔의 순간</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">8</span> <span class="keyword_rank"><a class="link_txt" href="?w=tot&amp;DA=R03&amp;q=%EC%83%9D%EB%B0%A9%EC%86%A1%20%EC%8B%AC%EC%95%BC%ED%86%A0%EB%A1%A0&amp;rtmaxcoll ...
# </div>
# <div class="g_comp_s" disp-attr="TOG">
# <div class="content_commend"> <div class="coll_tit"> <h2 class="tit">같이가치 추천글</h2> </div> <div class="coll_cont"> <ul class="list_major"> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91315/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91315&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=1',event);" target="_blank">가장 무서운 병 치매, 어떻게 예방하지?</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91636/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91636&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=2',event);" target="_blank">우리 동네 제로웨이스트 페스티벌, 궁금하다면!</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91271/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91271&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=3',event);" target="_blank">우리들의 옛이야기 한번 들어 볼래요?</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91953/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91953&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=4',event);" target="_blank">벼랑 끝에 선 어느 50대 가장의 눈물</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91754/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91754&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=5',event);" target="_blank">버려진 강아지, 꼭 내 모습 같아서...</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91712/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91712&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=6',event);" target="_blank">코로나19가 바꿔버린 어르신의 식탁</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91459/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91459&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=7',event);" target="_blank">잃어버린 식사의 즐거움, 다시 되찾고 싶어요</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91573/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91573&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=8',event);" target="_blank">사랑의 금쪽, 김치 한쪽을 나눠주세요!</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91295/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91295&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=9',event);" target="_blank">친구들을 집으로 초대하고 싶은 정아의 소원은</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/91831/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-91831&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=10',event);" target="_blank">밝은 미소를 되찾을 수 있는 방법은?</a> </li> </ul> </div> </div>
# </div>
# <div style="display:block;overflow:hidden;height:0;clear:both;font-size:0;line-height:0;visibility:hidden;">\00f0</div>
# </aside>
# </div>
# <a class="aside_quick" href="javascript:;">맨위로<span class="ico_rwd"></span></a>
# </article>
# <footer id="daumFoot">
# <div class="inner_footer" id="innerFooter">
# <div id="suggestFooter">
# <form class="d_sch" id="daumSearchFoot" method="get" name="search1">
# <fieldset class="fld_total">
# <legend class="screen_out">검색폼</legend>
# <input name="nil_ch" type="hidden" value=""/>
# <input name="rtupcoll" type="hidden" value=""/>
# <input name="nil_suggest" type="hidden" value="btn"/>
# <input name="DA" type="hidden" value="MEK"/>
# <input name="w" type="hidden" value="news"/>
# <input name="sq" type="hidden" value=""/>
# <input name="o" type="hidden" value=""/>
# <input name="sugo" type="hidden" value=""/>
# <input name="m" type="hidden" value=""/>
# <div class="box_searchbar">
# <div class="inner_searchbar">
# <input autocomplete="off" class="tf_keyword" id="q1" name="q" title="검색어 입력" type="text" value="제조"/>
# <button class="ico_ksearch btn_ksearch" id="schFooterSubmitBtn" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </div>
# </fieldset>
# </form>
# <div class="wrap_suggestBox"><div class="suggestBox box_sub reverseType" id="schFooterSuggestBox"></div></div>
# </div>
# <script type="text/javascript">
# (function(){
# var footerSearchModule = new SF.FooterSearchForm();
# footerSearchModule.init();
# })();
# </script>
# <div class="footer_comm">
# <a class="link_info" href="http://daumsearch.tistory.com" onclick="smartLog(this, 'pg=1&amp;p=10&amp;dc=CCC&amp;r=1', event);" target="_blank">검색블로그</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://cs.daum.net/faq/15/15649.html" onclick="smartLog(this, 'pg=1&amp;p=15&amp;dc=CCC&amp;r=1', event);" target="_blank">검색원칙</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://register.search.daum.net/" onclick="smartLog(this, 'pg=1&amp;p=9&amp;dc=CCC&amp;r=1', event);" target="_blank">사이트 등록 신청</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://mystore.kakao.com/" onclick="smartLog(this, 'pg=1&amp;p=14&amp;dc=CCC&amp;r=1', event);" target="_blank">카카오맵 매장관리</a><span class="txt_bar">|</span>
# <a class="link_info" href="http://partner.search.daum.net/partner/index.daum" onclick="smartLog(this, 'pg=1&amp;p=12&amp;dc=CCC&amp;r=1', event);" target="_blank">검색제휴</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://business.kakao.com/info/keywordad" onclick="smartLog(this, 'pg=1&amp;p=2&amp;dc=CCC&amp;r=1', event);" target="_blank">키워드광고</a><span class="txt_bar">|</span>
# <a class="link_info" href="http://local.biz.daum.net/" onclick="smartLog(this, 'pg=1&amp;p=3&amp;dc=CCC&amp;r=1', event);" target="_blank">로컬광고</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://business.kakao.com/info/crossmedia" onclick="smartLog(this, 'pg=1&amp;p=8&amp;dc=CCC&amp;r=1', event);" target="_blank">크로스미디어</a><span class="txt_bar">|</span>
# <a class="link_info" href="http://cs.daum.net/faq/15.html" onclick="smartLog(this, 'pg=1&amp;p=6&amp;dc=CCC&amp;r=1', event);" target="_blank">고객센터</a>
# <address class="copyright">   ⓒ <a class="link_daum" href="http://kakaocorp.com" onclick="smartLog(this, 'pg=1&amp;p=11&amp;dc=CCC&amp;r=1', event);" target="_blank">Kakao Corp.</a></address>
# </div>
# </div>
# </footer>
# </article>
# <script type="text/javascript">
# var __MiniDaumObj = null;
# var minidaum_options = null;
# (function() {
# minidaum_options = {
# bgType: "",
# enableLogoutRetun: true,
# disableHotissue: true,
# disableLogo: true,
# disableTracker: true,
# enableShield: false
# };
# })();
# </script>
# <script async="" charset="utf-8" defer="" src="//go.daum.net/minidaum_pc.daum" type="text/javascript"></script>
# <script type="text/javascript">
# SF.CommonModule && SF.CommonModule.init && SF.CommonModule.init();
# </script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# (function() {
# if (typeof TiaraTracker === 'undefined') {
# return;
# }
# var svcdomain = window.viewio === 'i' ? window.param_w + '.search.daum.net' : 'nate.search.daum.net';
# var pageName = window.param_w === 'tot' ? '통합검색' : window.param_w + '탭';
# var search = {
# search_term: window.topQuery,
# search_type:  window.param_da
# };
# TiaraTracker.getInstance()
# .setSvcDomain(svcdomain)
# .setPage(pageName)
# .setSection('검색결과')
# .trackPage('검색결과화면_조회')
# .actionKind("Search")
# .search(search)
# .track();
# })();
# </script>
# <script type="text/javascript">
# window.roosevelt_params_queue = window.roosevelt_params_queue || [];
# window.roosevelt_params_queue.push({
# channel_id: "dk", channel_label: "search", keyword: window.topQuery
# });
# </script>
# <script async="" src="//t1.daumcdn.net/midas/rt/dk_se/roosevelt_dk_se.js" type="text/javascript"></script>
# <script>
# (function(SF) {
# if (SF.compLogger && SF.compLogger.sendAllFromPage) {
# SF.compLogger.sendAllFromPage({
# ref: 'search'
# });
# }
# })(window.SF || {});
# </script>
# <!-- SA 삭제 -->
# <!-- end SA 삭제 -->
# </body>
# </html>

# %%
# '#newsColl > div.cont_divider > ul > li:nth-child(1) > div.wrap_cont > a'
# '#newsColl > div.cont_divider > ul > li:nth-child(2) > div.wrap_cont > a'
news_titles = soup.select('#newsColl > div.cont_divider > ul > li > div.wrap_cont > a')
news_titles
# Out:
# [<a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20211013173103250?f=o" onclick='smartLog(this, "dc=NNS&amp;d=265NO2uiCJgUHDJhg_&amp;pg=1&amp;r=1&amp;p=4&amp;rc=10&amp;e1=16FyB2ukEzHjC3cheN&amp;e3=0&amp;ext=dsid=265NO2uiCJgUHDJhg_", event, {"cpid": {"value": "16FyB2ukEzHjC3cheN"}});' target="_blank">김근하 "<b>제조</b>업은 값싼 인건비가 최고?..AI·IoT로 '맞춤형 <b>제조</b>' 전환해야"</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20211016055204157?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26zNpYXt6X3Jdr9KMR&amp;pg=1&amp;r=2&amp;p=4&amp;rc=10&amp;e1=16EJqgUM0mYHaQpZZ-&amp;e3=0&amp;ext=dsid=26zNpYXt6X3Jdr9KMR", event, {"cpid": {"value": "16EJqgUM0mYHaQpZZ-"}});' target="_blank">미 <b>제조</b>업지수 한달새 급락..공급망 대란 충격 현실로(종합)</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20211013183317249?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26Y0GzJ02NcpvqSjFH&amp;pg=1&amp;r=3&amp;p=4&amp;rc=10&amp;e1=16xPi3xTTvS9eQchSd&amp;e3=0&amp;ext=dsid=26Y0GzJ02NcpvqSjFH", event, {"cpid": {"value": "16xPi3xTTvS9eQchSd"}});' target="_blank">[김규성 칼럼] <b>제조</b>업 엑소더스 부추기는 정부</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20211015135445202?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26SAVE7zs0WP_uFKH-&amp;pg=1&amp;r=4&amp;p=4&amp;rc=10&amp;e1=16Fbn8iLTIqdeOvaST&amp;e3=0&amp;ext=dsid=26SAVE7zs0WP_uFKH-", event, {"cpid": {"value": "16Fbn8iLTIqdeOvaST"}});' target="_blank">톤28, 국제수준 COSMOS ORGANIC <b>제조</b> 시설 인증</a>,
#  <a class="tit_main fn_tit_u" href="https://cp.news.search.daum.net/p/111719635" onclick='smartLog(this, "dc=NNS&amp;d=26o8YLrE1nTPSQXw6k&amp;pg=1&amp;r=5&amp;p=4&amp;rc=10&amp;e1=166RjCA9uERLap2Hlp&amp;e3=0&amp;ext=dsid=26o8YLrE1nTPSQXw6k", event, {"cpid": {"value": "166RjCA9uERLap2Hlp"}});' target="_blank">국회·식약처 임의<b>제조</b> 처벌강화 공감, 법안 탄력받나</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20211013171302575?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26Psjs0F281ElbK1vv&amp;pg=1&amp;r=6&amp;p=4&amp;rc=10&amp;e1=16FyB2ukEzHjC3cheN&amp;e3=0&amp;ext=dsid=26Psjs0F281ElbK1vv", event, {"cpid": {"value": "16FyB2ukEzHjC3cheN"}});' target="_blank">김근하 대표 "중견·중소 <b>제조</b>업의 생존..스마트 플랫폼에 달렸다"</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20211014120036740?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26UOLM4iXO9dfbuZrq&amp;pg=1&amp;r=7&amp;p=4&amp;rc=10&amp;e1=16JfL24RCJKYboAM86&amp;e3=0&amp;ext=dsid=26UOLM4iXO9dfbuZrq", event, {"cpid": {"value": "16JfL24RCJKYboAM86"}});' target="_blank">중소 <b>제조</b>업 64.8% "주52시간제 힘들다"</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20211013111723740?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26lR0Bizu_z-ors6UD&amp;pg=1&amp;r=8&amp;p=4&amp;rc=10&amp;e1=16iegqg-unkCM79rj6&amp;e3=0&amp;ext=dsid=26lR0Bizu_z-ors6UD", event, {"cpid": {"value": "16iegqg-unkCM79rj6"}});' target="_blank">기저효과로 취업자 늘었지만..글로벌 공급망 쇼크로 경제 주축 <b>제조</b>업 일자리 '마이너스'</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20211014070015907?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26W2zVUTL38uhgrqcs&amp;pg=1&amp;r=9&amp;p=4&amp;rc=10&amp;e1=16JfL24RCJKYboAM86&amp;e3=0&amp;ext=dsid=26W2zVUTL38uhgrqcs", event, {"cpid": {"value": "16JfL24RCJKYboAM86"}});' target="_blank">'30대'만 비껴간 고용시장 온기.."도소매업·<b>제조</b>업 부진 영향"</a>,
#  <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20211014132708877?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26HL8f4fu2mvfYfAgd&amp;pg=1&amp;r=10&amp;p=4&amp;rc=10&amp;e1=16mKHIlsR6WVoQImSS&amp;e3=0&amp;ext=dsid=26HL8f4fu2mvfYfAgd", event, {"cpid": {"value": "16mKHIlsR6WVoQImSS"}});' target="_blank">포항시, 애플과 <b>제조</b>업 스마트도시 만들기 본격 추진</a>]

# %%
for i, one_news in enumerate(news_titles):
    print('{}번째 기사제목 : {}'.format(i+1, one_news.text))
# Out:
# 1번째 기사제목 : 김근하 "제조업은 값싼 인건비가 최고?..AI·IoT로 '맞춤형 제조' 전환해야"
# 2번째 기사제목 : 미 제조업지수 한달새 급락..공급망 대란 충격 현실로(종합)
# 3번째 기사제목 : [김규성 칼럼] 제조업 엑소더스 부추기는 정부
# 4번째 기사제목 : 톤28, 국제수준 COSMOS ORGANIC 제조 시설 인증
# 5번째 기사제목 : 국회·식약처 임의제조 처벌강화 공감, 법안 탄력받나
# 6번째 기사제목 : 김근하 대표 "중견·중소 제조업의 생존..스마트 플랫폼에 달렸다"
# 7번째 기사제목 : 중소 제조업 64.8% "주52시간제 힘들다"
# 8번째 기사제목 : 기저효과로 취업자 늘었지만..글로벌 공급망 쇼크로 경제 주축 제조업 일자리 '마이너스'
# 9번째 기사제목 : '30대'만 비껴간 고용시장 온기.."도소매업·제조업 부진 영향"
# 10번째 기사제목 : 포항시, 애플과 제조업 스마트도시 만들기 본격 추진

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame(columns=['제목'])
dataframe
# Out:
# Empty DataFrame
# Columns: [제목]
# Index: []

# %%
for i, one_news in enumerate(news_titles):
    dataframe = dataframe.append({'제목' : one_news.text}, ignore_index=True)
dataframe
# Out:
#                                                  제목
# 0     김근하 "제조업은 값싼 인건비가 최고?..AI·IoT로 '맞춤형 제조' 전환해야"
# 1                 미 제조업지수 한달새 급락..공급망 대란 충격 현실로(종합)
# 2                         [김규성 칼럼] 제조업 엑소더스 부추기는 정부
# 3                 톤28, 국제수준 COSMOS ORGANIC 제조 시설 인증
# 4                      국회·식약처 임의제조 처벌강화 공감, 법안 탄력받나
# 5              김근하 대표 "중견·중소 제조업의 생존..스마트 플랫폼에 달렸다"
# 6                         중소 제조업 64.8% "주52시간제 힘들다"
# 7  기저효과로 취업자 늘었지만..글로벌 공급망 쇼크로 경제 주축 제조업 일자리 '마이너스'
# 8              '30대'만 비껴간 고용시장 온기.."도소매업·제조업 부진 영향"
# 9                      포항시, 애플과 제조업 스마트도시 만들기 본격 추진

# %%
dataframe = pd.DataFrame(columns=['제목'])
dataframe
# Out:
# Empty DataFrame
# Columns: [제목]
# Index: []

# %%
for i, one_news in enumerate(news_titles):
    title = one_news.text.replace("'","")
    title = title.replace('"','')
    title = title.replace('\\','')
    dataframe = dataframe.append({'제목' : one_news.text}, ignore_index=True)
dataframe
# Out:
#                                                  제목
# 0     김근하 "제조업은 값싼 인건비가 최고?..AI·IoT로 '맞춤형 제조' 전환해야"
# 1                 미 제조업지수 한달새 급락..공급망 대란 충격 현실로(종합)
# 2                         [김규성 칼럼] 제조업 엑소더스 부추기는 정부
# 3                 톤28, 국제수준 COSMOS ORGANIC 제조 시설 인증
# 4                      국회·식약처 임의제조 처벌강화 공감, 법안 탄력받나
# 5              김근하 대표 "중견·중소 제조업의 생존..스마트 플랫폼에 달렸다"
# 6                         중소 제조업 64.8% "주52시간제 힘들다"
# 7  기저효과로 취업자 늘었지만..글로벌 공급망 쇼크로 경제 주축 제조업 일자리 '마이너스'
# 8              '30대'만 비껴간 고용시장 온기.."도소매업·제조업 부진 영향"
# 9                      포항시, 애플과 제조업 스마트도시 만들기 본격 추진

# %%
dataframe = pd.DataFrame(columns=['제목'])
for i in range(3):
    url = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EC%A0%9C%EC%A1%B0&p=' + str(i+1)

    response = requests.get(url)
    if response.status_code == 200:
        html = response.text
        soup = BeautifulSoup(html, 'html.parser')
        news_titles = soup.select('#newsColl > div.cont_divider > ul > li > div.wrap_cont > a')
        for i, one_news in enumerate(news_titles):
            one_news = one_news.text
            one_news = one_news.replace('\\','')
            one_news = one_news.replace('"','')
            one_news = one_news.replace("'",'')
            one_news = one_news.replace(",","")
            one_news = one_news.replace(".","")
            dataframe = dataframe.append({'제목' : one_news}, ignore_index=True)
            
    else:
        print('{} 응답.'.format(response.status_code))

# %%
dataframe.tail()
# Out:
#                                   제목
# 25       이산화탄소 배출없는 친환경 배터리 제조 공정 개발
# 26  SMATEC2021 ‘스마트 제조의 미래’로 컨퍼런스 개최
# 27   수소 제조부터 수송 현지 판매까지일본 종합상사의 수소사업
# 28          서울창업허브 아마존에서 제조 스타트업 키운다
# 29          1조 클럽 한국 제조기업코로나에도 2배 늘어

# %%
dataframe.to_csv('제조업검색 뉴스 제목.csv', sep=',', encoding='utf-8-sig', index=False)

# %% [markdown]
# !conda install -c conda-forge -y wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
# %matplotlib inline

# %%
new_title_csv = pd.read_csv('제조업검색 뉴스 제목.csv')
new_title_csv.tail()
# Out:
#                                   제목
# 25       이산화탄소 배출없는 친환경 배터리 제조 공정 개발
# 26  SMATEC2021 ‘스마트 제조의 미래’로 컨퍼런스 개최
# 27   수소 제조부터 수송 현지 판매까지일본 종합상사의 수소사업
# 28          서울창업허브 아마존에서 제조 스타트업 키운다
# 29          1조 클럽 한국 제조기업코로나에도 2배 늘어

# %%
title_list = list(np.array(new_title_csv['제목'].to_list()))
title_list
# Out:
# ['김근하 제조업은 값싼 인건비가 최고?AI·IoT로 맞춤형 제조 전환해야',
#  '미 제조업지수 한달새 급락공급망 대란 충격 현실로(종합)',
#  '[김규성 칼럼] 제조업 엑소더스 부추기는 정부',
#  '톤28 국제수준 COSMOS ORGANIC 제조 시설 인증',
#  '국회·식약처 임의제조 처벌강화 공감 법안 탄력받나',
#  '김근하 대표 중견·중소 제조업의 생존스마트 플랫폼에 달렸다',
#  '중소 제조업 648% 주52시간제 힘들다',
#  '기저효과로 취업자 늘었지만글로벌 공급망 쇼크로 경제 주축 제조업 일자리 마이너스',
#  '30대만 비껴간 고용시장 온기도소매업·제조업 부진 영향',
#  '포항시 애플과 제조업 스마트도시 만들기 본격 추진',
#  '취업자 67만 명 늘어났지만제조·대면서비스는 여전히 고전',
#  '3·4분기 제조업 경기 먹구름대부분 업종 BSI 하락세',
#  '포항시 애플과 함께 제조업 스마트화 신산업 육성 나서',
#  '4분기 제조업 경기 기대감 주춤디스플레이·조선 하락 전망',
#  '제조 메타버스로 경남 스마트 제조혁신 대비한다',
#  '외국인근로자 5만8천명 감소제조업체 65% 쿼터 확대',
#  '친환경 플라스틱 제조 최적화된 금형 설비 개발된다',
#  '절대 공유 못해모더나가 백신 제조법 공개 안하는 진짜 이유',
#  '충북 스마트공장 구축으로 제조혁신 선두 노린다',
#  '새만금산단 차세대 태양전지 제조기업 대형 투자협약',
#  '투자받기 힘든 제조 스타트업 안 망하려 온종일 로봇과 씨름',
#  'KATECH 제조기술연구센터 차량부품 평가인증 지원 기반구축사업 완료',
#  '모더나 코로나 백신 제조법 공유 안한다자체 생산이 최선',
#  '자영업·도소매·제조업 여전히 어려워완전한 고용 회복 먼 길',
#  '울산보건환경연구원 식품 제조용 지하수 바이러스 검사',
#  '이산화탄소 배출없는 친환경 배터리 제조 공정 개발',
#  'SMATEC2021 ‘스마트 제조의 미래’로 컨퍼런스 개최',
#  '수소 제조부터 수송 현지 판매까지일본 종합상사의 수소사업',
#  '서울창업허브 아마존에서 제조 스타트업 키운다',
#  '1조 클럽 한국 제조기업코로나에도 2배 늘어']

# %%
width = 640
height = 480
font = 'C:/Windows/Fonts/batang.ttc'  # 윈도우의 폰트 경로 
# font = '/system'

stop_words = '제조업, 제조'
max_words = 100
backgroud_color = 'black'
max_font_size = 100
min_font_size = 1

colormap = 'rainbow_r'

wordcloud = WordCloud(
    width=width,
    height=height,
    font_path = font,
    max_font_size=max_font_size,
    min_font_size=min_font_size,
    max_words=max_words,
    background_color=backgroud_color,
    stopwords=stop_words
    
                        )

# %%
wordcloud = wordcloud.generate_from_text(' '.join(title_list))

# %%
wordcloud_array = wordcloud.to_array()

# %%
fig = plt.figure(figsize = (10,10))
plt.imshow(wordcloud_array)
plt.axis('off')
plt.show()

# %%
from PIL import Image
word_mask = np.array(Image.open('word_mask3.png'))

# %%
wordcloud = WordCloud(
    width=width,
    height=height,
    font_path = font,
    max_font_size=max_font_size,
    min_font_size=min_font_size,
    max_words=max_words,
    background_color=backgroud_color,
    stopwords=stop_words,
    
    mask=word_mask
    
                        )

# %%
wordcloud = wordcloud.generate_from_text(' '.join(title_list))

# %%
wordcloud_array = wordcloud.to_array()

# %%
fig = plt.figure(figsize = (10,10))
plt.imshow(wordcloud_array)
# plt.axis('off')
plt.show()

# %%
fig.savefig('word_cloud.png')

# %%
word_mask = np.array(Image.open('word_mask4.png'))
width = 259
height = 195
wordcloud = WordCloud(
    width=width,
    height=height,
    font_path = font,
    max_font_size=max_font_size,
    min_font_size=min_font_size,
    max_words=max_words,
    background_color=backgroud_color,
    stopwords=stop_words,
    
    mask=word_mask
    
                        )
wordcloud = wordcloud.generate_from_text(' '.join(title_list))
wordcloud_array = wordcloud.to_array()
fig = plt.figure(figsize = (10,10))
plt.imshow(wordcloud_array)
# plt.axis('off')
plt.show()
